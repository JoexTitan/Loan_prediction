# %% [markdown]
# ![Rapid Finance 2.png](data:image/png;base64,...)

# %% [markdown]
# ##**INTRODUCTION**

# %% [markdown]
# # Loan Prediction Data
#
# https://www.kaggle.com/datasets/altruistdelhite04/loan-prediction-problem-dataset

# %%
# Importing the required libraries & modules
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Data Collection and Processing

# %%
# Let us begin by analyzing the categorical variables in our data set

# %%
# Let us now analyze the numerical variables in our data set

# %%
# File: loan_prediction_dataset.csv
loan_df = pd.read_csv("/content/loan_prediction_dataset.csv")
type(loan_df)
# Out:
# pandas.core.frame.DataFrame

# %%
##################### Getting familiar with the data at hand #################################
# loan_df.head(5)
# loan_df.tail(5)
# loan_df.info()
# loan_df.shape()
# loan_df.describe()
# loan_df.isnull().sum()
# loan.df.ColNAME.value_counts()

# loan_df = loan_df.dropna()

# loan.df.replace({'Loan_Status':{'N':0,'Y':1}}, 
#                  'Gender':{'Female':0,'Male':1}},
#                  'Self_Employed':{'No':0,'Yes':1}}, .... , inplace=True)

# loan.df.replace(to_replace='3+', value=4)

'''
The process of replacing missing/null values from the data 
Is called Imputation. Since some of the values are missing
we might want to consider to replace them with a mean/median 
value, however, if we are dealing with chategorical variables
we cannot do that - this can only be done with numerical values.
When dropping null values if one element within a column is missing
then the entire row is dropped - unless we are able to imputate/fill-in. 


Label Encoding refers to the conversion of chategorical data into 
a numerical form - converting them into the machine-readable form. 
Machine learning algorithms can then decide in a better way how 
those elements must be operated. It is an important pre-processing 
step for the structured dataset in supervised learning.
'''

# %%
loan_df.head(5)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
loan_df.tail(5)
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
# Scheme of the data set is described by info() function
loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
# 614 rows, 13 columns
loan_df.shape
# Out:
# (614, 13)

# %%
# getting familiarized with the data 
loan_df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
# The percentage of data that is missing from each column
(loan_df.isnull().sum() / loan_df.shape[0]) * 100

# The percentage of data that is present in the columns
(1 - (loan_df.isnull().sum() / loan_df.shape[0])) * 100
# Out:
# Loan_ID              100.000000
# Gender                97.882736
# Married               99.511401
# Dependents            97.557003
# Education            100.000000
# Self_Employed         94.788274
# ApplicantIncome      100.000000
# CoapplicantIncome    100.000000
# LoanAmount            96.416938
# Loan_Amount_Term      97.719870
# Credit_History        91.856678
# Property_Area        100.000000
# Loan_Status          100.000000
# dtype: float64

# %% [markdown]
# ## Imputation Step Using KNNImputer

# %%
from sklearn.impute import KNNImputer

impute_knn = KNNImputer(n_neighbors=5)
num = [col for col in loan_df.columns if loan_df[col].dtypes!='O']
new = pd.DataFrame(impute_knn.fit_transform(loan_df[num]))

# %%
loan_df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  614.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   84.037468          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.250000         360.00000
# 50%        3812.500000        1188.500000  129.000000         360.00000
# 75%        5795.000000        2297.250000  164.750000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      614.000000
# mean         0.855049
# std          0.352339
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
new.columns=['AI','CI','LA','LAT','CH']
new.describe()
# Out:
#                  AI            CI          LA        LAT          CH
# count    614.000000    614.000000  614.000000  614.00000  614.000000
# mean    5403.459283   1621.245798  146.412162  342.03127    0.855049
# std     6109.041673   2926.248369   84.037468   64.47906    0.352339
# min      150.000000      0.000000    9.000000   12.00000    0.000000
# 25%     2877.500000      0.000000  100.250000  360.00000    1.000000
# 50%     3812.500000   1188.500000  129.000000  360.00000    1.000000
# 75%     5795.000000   2297.250000  164.750000  360.00000    1.000000
# max    81000.000000  41667.000000  700.000000  480.00000    1.000000

# %%
loan_df['Loan_Amount_Term'] = new['LAT']

loan_df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  614.000000         614.00000
# mean       5403.459283        1621.245798  146.412162         342.03127
# std        6109.041673        2926.248369   84.037468          64.47906
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.250000         360.00000
# 50%        3812.500000        1188.500000  129.000000         360.00000
# 75%        5795.000000        2297.250000  164.750000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      614.000000
# mean         0.855049
# std          0.352339
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
loan_df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
loan_df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  614.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   84.037468          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.250000         360.00000
# 50%        3812.500000        1188.500000  129.000000         360.00000
# 75%        5795.000000        2297.250000  164.750000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      614.000000
# mean         0.855049
# std          0.352339
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
loan_df['LoanAmount'] = loan_df.LoanAmount.fillna(loan_df['LoanAmount'].mean())
loan_df['Loan_Amount_Term'] = loan_df['Loan_Amount_Term'].fillna(loan_df['Loan_Amount_Term'].median())

# %%
loan_df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
loan_df = loan_df.dropna()
loan_df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
# imputation is the process at which we fill in the null values with the mean/median
# label encoding refers to the conversion of character type elements to numberic

# %%
loan_df.head()
loan_df.Dependents.value_counts()
# Out:
# 0     274
# 2      85
# 1      80
# 3+     41
# Name: Dependents, dtype: int64

# %%
loan_df = loan_df.replace(to_replace='3+',value=4)
loan_df.Dependents.value_counts()
# Out:
# 0    274
# 2     85
# 1     80
# 4     41
# Name: Dependents, dtype: int64

# %%
# Data Pre-processing

# %%
loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 480 entries, 1 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            480 non-null    object
#  1   Gender             480 non-null    object
#  2   Married            480 non-null    object
#  3   Dependents         480 non-null    object
#  4   Education          480 non-null    object
#  5   Self_Employed      480 non-null    object
#  6   ApplicantIncome    480 non-null    int64
#  7   CoapplicantIncome  480 non-null    float64
#  8   LoanAmount         480 non-null    float64
#  9   Loan_Amount_Term   480 non-null    float64
#  10  Credit_History     480 non-null    float64
#  11  Property_Area      480 non-null    object
#  12  Loan_Status        480 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 52.5+ KB

# %%
loan_df.head(10)
# Out:
#      Loan_ID Gender Married Dependents     Education Self_Employed  \
# 1   LP001003   Male     Yes          1      Graduate            No
# 2   LP001005   Male     Yes          0      Graduate           Yes
# 3   LP001006   Male     Yes          0  Not Graduate            No
# 4   LP001008   Male      No          0      Graduate            No
# 5   LP001011   Male     Yes          2      Graduate           Yes
# 6   LP001013   Male     Yes          0  Not Graduate            No
# 7   LP001014   Male     Yes          4      Graduate            No
# 8   LP001018   Male     Yes          2      Graduate            No
# 9   LP001020   Male     Yes          1      Graduate            No
# 10  LP001024   Male     Yes          2      Graduate            No
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1              4583             1508.0       128.0             360.0
# 2              3000                0.0        66.0             360.0
# ...

# %%
# convert categorical columns to numerical values
loan_df.replace({'Gender':{'Female':0,'Male':1},
                'Married':{'No':0,'Yes':1},
                'Education':{'Not Graduate':0,'Graduate':1},
                'Self_Employed':{'No':0,'Yes':1},
                'Property_Area':{'Rural':0,'Semiurban':1,'Urban':2},
                'Loan_Status':{'N':0,'Y':1}},inplace=True)

# %%
# Exploroatory Step

# %%
loan_df.head()
# Out:
#     Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0  LP001002     1.0      0.0          0          1            0.0
# 1  LP001003     1.0      1.0          1          1            0.0
# 2  LP001005     1.0      1.0          0          1            1.0
# 3  LP001006     1.0      1.0          0          0            0.0
# 4  LP001008     1.0      0.0          0          1            0.0
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History  Property_Area  Loan_Status
# 0             1.0              2            1
# 1             1.0              0            0
# ...

# %%
loan_df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
cols = ['Gender', 'Married', 'Education', 'Self_Employed', 'Property_Area']

def x(cols):
  for i in range(331:336):
    plt.subplot(i)
    sns.countplot(loan_df[cols[i]],hue=loan_df['Loan_Status'])
 
x(cols)
#sns.countplot(loan_df[x(cols)],hue=loan_df['Loan_Status'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-6fd9b8aed272> in <module>()
#       6     sns.countplot(loan_df[cols[i]],hue=loan_df['Loan_Status'])
#       7
# ----> 8 x(cols)
#       9 #sns.countplot(loan_df[x(cols)],hue=loan_df['Loan_Status'])
#
# <ipython-input-72-6fd9b8aed272> in x(cols)
#       3 def x(cols):
#       4   for i in range(5):
# ----> 5     plt.subplot(i)
#       6     sns.countplot(loan_df[cols[i]],hue=loan_df['Loan_Status'])
#       7
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1028
#    1029     fig = gcf()
# -> 1030     a = fig.add_subplot(*args, **kwargs)
#    1031     bbox = a.bbox
#    1032     byebye = []
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1379             if not 100 <= args[0] <= 999:
# ...

# %%
plt.figure(figsize = (300, 150))
sns.set(font_scale = 15)
plt.subplot(331)
sns.countplot(loan_df['Gender'],hue=loan_df['Loan_Status'])

plt.subplot(332)
sns.countplot(loan_df['Married'],hue=loan_df['Loan_Status'])

plt.subplot(333)
sns.countplot(loan_df['Education'],hue=loan_df['Loan_Status'])

plt.subplot(334)
sns.countplot(loan_df['Self_Employed'],hue=loan_df['Loan_Status'])

plt.subplot(335)
sns.countplot(loan_df['Property_Area'],hue=loan_df['Loan_Status'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %%
loan_df.hist(bins=50, figsize=(30,20))
plt.show()

# %%
sns.countplot(x='Gender',hue='Loan_Status',data=loan_df)

# %%
sns.countplot(x="Married",hue='Loan_Status',data=loan_df)

# %%
sns.countplot(x="Education",hue='Loan_Status',data=loan_df)

# %%
sns.countplot(x='Self_Employed',hue='Loan_Status',data=loan_df)

# %%
sns.countplot(x='Property_Area',hue='Loan_Status',data=loan_df)

# %%
loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    float64
#  2   Married            611 non-null    float64
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    int64
#  5   Self_Employed      582 non-null    float64
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    int64
#  12  Loan_Status        614 non-null    int64
# dtypes: float64(7), int64(4), object(2)
# memory usage: 62.5+ KB

# %% [markdown]
# ## Train Test Split

# %%
X = loan_df.drop(columns=['Loan_ID','Loan_Status'],axis=1)
Y = loan_df.Loan_Status

# %%
print(X,Y)
# Out:
#      Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 1         1        1          1          1              0             4583
# 2         1        1          0          1              1             3000
# 3         1        1          0          0              0             2583
# 4         1        0          0          1              0             6000
# 5         1        1          2          1              1             5417
# ..      ...      ...        ...        ...            ...              ...
# 609       0        0          0          1              0             2900
# 610       1        1          4          1              0             4106
# 611       1        1          1          1              0             8072
# 612       1        1          2          1              0             7583
# 613       0        0          0          1              1             4583
#
# ...

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.1,stratify=Y,random_state=2)

# %%
# X_train,Y_test has 90% of data and the correlating answers
# X_test,Y_test has 10% of data and no correlated answers
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (480, 11) (432, 11) (48, 11)

# %%
# Let us use the Support Vector Machine Model

# %%
classifier = svm.SVC(kernel='linear')

# %%
# Training the SVM Model
classifier.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %%
# A) Model Evaluation - accuracy score on the training data
X_train_prediction = classifier.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction,Y_train)

# %%
print(f'Accuracy on the training data: {training_data_accuracy}')
# Out:
# Accuracy on the training data: 0.7986111111111112

# %%
# B) Model Evaluation - accuracy score on the test data -> MUCH MORE IMPORTANT
X_test_prediction = classifier.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction,Y_test)

# %%
print(f'Accuracy on the test data: {test_data_accuracy}')
# Out:
# Accuracy on the test data: 0.8333333333333334

# %% [markdown]
# ## Making a predictive system

# %% [markdown]
# https://www.youtube.com/watch?v=fiz1ORTBGpY&list=PLfFghEzKVmjvuSA67LszN1dZ-Dd_pkus6&ab_channel=Siddhardhan
#
# 45.42 mins - predictive system / also on your home screen
